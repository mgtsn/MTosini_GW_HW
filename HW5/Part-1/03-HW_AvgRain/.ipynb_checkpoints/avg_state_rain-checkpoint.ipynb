# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
file = 'Resources/avg_rain_state.csv'
rain = pd.read_csv(file)
rain.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
plt.figure(figsize=(20,3))
plt.bar(rain['State'], rain['Inches'], color='r', alpha=.5)
plt.xticks(rotation=90)
plt.yticks([0,25,50])
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.YTick at 0x1cd2000c358>,
#   <matplotlib.axis.YTick at 0x1cd20001ba8>,
#   <matplotlib.axis.YTick at 0x1cd1fd96b00>],
#  <a list of 3 Text yticklabel objects>)

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space

# %%
# Set x and y limits
plt.ylim(0,75)
plt.rcParams['figure.figsize'] = [12, 14]

# %%
# Set a Title and labels
plt.title('Average Rain per State')
plt.xlabel('State')
plt.ylabel('Average Rainfall (Inches)')
plt.tight_layout()

# %%
# Save our graph and show the grap
plt.savefig('Output.png')
plt.show()
