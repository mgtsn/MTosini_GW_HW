# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = 'Resources/2016-FCC-New-Coders-Survey-Data.csv'

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
df = pd.read_csv(file, low_memory=True)
df.head()
# Out:
# C:\Users\Morgan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
df = df.iloc[:, [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# 1             NaN  between 100,000 and 1 million  ...
# 2             NaN            more than 1 million  ...
# 3             NaN            more than 1 million  ...
# 4             NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren  HoursLearning   Income  \
# 0  Employed for wages    male         0.0           30.0  32000.0
# 1  Employed for wages    male         NaN           30.0  15000.0
# 2  Employed for wages    male         NaN           20.0  48000.0
# 3  Employed for wages  female         NaN           20.0  43000.0
# 4  Employed for wages  female         NaN           25.0   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Change reading 0 and 1 to No and Yes, respectively
df = df.replace({0:'No', 1:'Yes'})
df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# 2            NaN            more than 1 million  ...
# 3            NaN            more than 1 million  ...
# 4            NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren HoursLearning   Income  \
# 0  Employed for wages    male          No            30  32000.0
# 1  Employed for wages    male         NaN            30  15000.0
# 2  Employed for wages    male         NaN            20  48000.0
# 3  Employed for wages  female         NaN            20  43000.0
# 4  Employed for wages  female         NaN            25   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Extract rows for only those who attended a bootcamp
df = df.loc[df['AttendedBootcamp'] == 'Yes']
df.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo      BootcampName  BootcampPostSalary BootcampRecommend  \
# 93                 No    Codify Academy                 NaN                No
# 97                 No    DaVinci Coders             45000.0                No
# 130               Yes     Coder Foundry             75000.0               Yes
# 159                No  General Assembly                 NaN                No
# 188               Yes               NaN                 NaN                No
#
#     ChildrenNumber                 CityPopulation  ...  \
# 93             NaN  between 100,000 and 1 million  ...
# 97             NaN            more than 1 million  ...
# 130              3              less than 100,000  ...
# 159            NaN  between 100,000 and 1 million  ...
# 188            NaN  between 100,000 and 1 million  ...
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# 97   United States of America                   software development
# 130  United States of America                   software development
# 159  United States of America                                    NaN
# 188                    Canada                                    NaN
#
#                          EmploymentStatus  Gender HasChildren HoursLearning  \
# 93           Self-employed business owner    male         NaN            20
# 97                     Employed for wages    male          No            10
# 130                    Employed for wages    male         Yes            30
# 159  Not working and not looking for work  female         NaN            30
# 188      Not working but looking for work  female         NaN            60
#
#       Income           JobRoleInterest                        SchoolDegree  \
# 93   67000.0                       NaN                   bachelor's degree
# 97   40000.0                       NaN  master's degree (non-professional)
# 130  75000.0                       NaN      some college credit, no degree
# 159      NaN  Full-Stack Web Developer      some college credit, no degree
# 188      NaN                       NaN      some college credit, no degree
#
#     SchoolMajor
# 93      Biology
# 97        Music
# 130         NaN
# 159         NaN
# 188         NaN
#
# [5 rows x 21 columns]

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
v = df['BootcampName'].value_counts()
dfbc = pd.DataFrame(v)
dfbc = dfbc.reset_index()
dfbc.columns = ['BootcampName', 'Attendees']
dfbc.head()
# Out:
#             BootcampName  Attendees
# 0       General Assembly         90
# 1        Flatiron School         54
# 2           Dev Bootcamp         48
# 3          The Iron Yard         40
# 4  Prime Digital Academy         30

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
df2 = df.groupby('BootcampName')
#df1 = df2.loc[df2['BootcampRecommend'] == 'Yes']
#df3 = df2['BootcampRecommend'].value_counts()
#df2.loc[df2['BootcampRecommend']=='Yes']
#df3 = pd.DataFrame({df2[]})
#df1.head()
df2 = df2['BootcampName', 'BootcampRecommend']
df2.head()
# Out:
#                                             BootcampName BootcampRecommend
# 93                                        Codify Academy                No
# 97                                        DaVinci Coders                No
# 130                                        Coder Foundry               Yes
# 159                                     General Assembly                No
# 188                                                  NaN                No
# 206                                             Thinkful                No
# 209                                      Flatiron School               Yes
# 236                                     General Assembly                No
# 272                                          DevMountain               Yes
# 273                                        The Iron Yard               Yes
# 285                                               Codeup               Yes
# 315                                     General Assembly                No
# 316                                         Code Fellows               Yes
# 328                                              Bloc.io               Yes
# 426                                     General Assembly               Yes
# 435                                 The Firehose Project               Yes
# 449                                     General Assembly               Yes
# 465                                Prime Digital Academy               Yes
# 470                                Prime Digital Academy               Yes
# 478                                Prime Digital Academy               Yes
# 481                                Prime Digital Academy               Yes
# 488                                Prime Digital Academy               Yes
# 505    Free Code Camp is not a bootcamp - please scro...               Yes
# 510                                      Flatiron School               Yes
# 522                                            Galvanize                No
# 525                                                  Ada               Yes
# 533                                                  NaN               Yes
# 543                                           Skillcrush               Yes
# 549                                         Hack Reactor               Yes
# 608                                                  NaN                No
# ...                                                  ...               ...
# 14085                                          CodeaCamp               Yes
# 14090                          Nashville Software School               Yes
# 14096                                        Coder's Lab               Yes
# 14102                                         Skillcrush               Yes
# 14106                                 Academia de Código               Yes
# 14107                                 Academia de Código               Yes
# 14109                                CODEcamp Charleston               Yes
# 14110                                Origin Code Academy               Yes
# 14111                                        TalentBuddy               NaN
# 14112                                          CodeaCamp               Yes
# 14114                                 Academia de Código               Yes
# 14115                                         10x.org.il                No
# 14275                                      We Got Coders               Yes
# 14322                                          CodeaCamp               Yes
# 14365                                  Astro Code School                No
# 14396                                          CodeaCamp               Yes
# 14416                                         10x.org.il                No
# 14467                                  Telegraph Academy               Yes
# 14532                                              Metis               Yes
# 14562                                      Bitmaker Labs               Yes
# 14643                                     Codify Academy                No
# 14695                                           AcadGild               Yes
# 14701                                          Devschool               Yes
# 14751                          Orange County Code School                No
# 14766                                     DaVinci Coders                No
# 14987                                          LAMP Camp               Yes
# 15400                                      Fire Bootcamp                No
# 15420                                     We Can Code IT                No
# 15436                                     Starter League               Yes
# 15593                                     Camp Code Away                No
#
# [389 rows x 2 columns]

# %%
# Merge the two created data frames on the name of tbe bootcamp

# %%
# Calculate percentage of eac bootcamp's students who are recommenders

# %%
# Export to excel and remove index
